# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshini1507/DA_Python/blob/main/DA_project_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("car_Dekho_DA.csv")

# %%
#Gives the first 5 rows in the data set
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#Gives the stastical representation of the given data set
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# 1)From which manufacturing year to which manufacturing year vehicles are present in this data ?
#
#   Year: 2003-2008 (min Year to max Year) -> using df.describe()

# %% [markdown]
# 2)What is the lowest price to which a vehicle is sold ?
#
# Selling_Price: 0.100000 (lowest/min) -> using df.describe()

# %% [markdown]
# 3)What is the highest price to which a vehicle is sold ?
#
#   Selling_Price: 35.000000 (highest/max) -> using df.describe()

# %% [markdown]
# 4)How many records are there in this data ?
#
#   301 records by COUNT in df.describe()

# %%
#Gives the data types and the Non-Null Count of the variables in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# 5)Are there any missing records in this data ?
#
#    0 missing records as there are no null values in this data -> using df.info()

# %%
#Gives the count of unique values in the data
df["Car_Name"].nunique()
# Out:
# 98

# %% [markdown]
# 6)How many different vehicles are present in this data ?
#
#   There are 98 different vehicles in this data -> using df.nunique()

# %%
#Gives the count of all the values of unique values in the data
df["Car_Name"].value_counts()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %% [markdown]
# 7)Which is the most sold vehicle in this data ?
#
# The most sold vehicles in this data are City cars -> using df.value_counts()

# %%
#Gives the unique values existing in the data
df["Fuel_Type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df["Fuel_Type"].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %% [markdown]
# 8)Does the database include any CNG vehicle ? If yes how many of them are there ?
#
#   Yes, the database include CNG Vehicle -> using df.unique()
#
#   There are 2 CNG vehicles -> using df.value_counts()

# %%
df["Seller_Type"].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %% [markdown]
# 9)How many vehicles here are for sell from Individuals directly ?
#
#  Seller_Type: Individuals(106) -> using df.value_counts()

# %%
df["Transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %% [markdown]
# 10)Does this database contain auto transmission vehicles ? If yes how many of them are there ?
#
# Yes, This database contain auto transmission vehicles -> using df.unique()
#
# Transmission: Automatic(40) -> by using df.value_counts()

# %%
df["Owner"].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# 11)How many single person owned vehicles are there in this database ?
#
# Owner: 1/single (10) -> by using value_counts()

# %%
#Highest depreciation observed from the vehicles in the data
df["Depreciation"]=df["Present_Price"]-df["Selling_Price"]
df.loc[df.Depreciation==df.Depreciation.max()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010           35.0           92.6       78000    Diesel
#
#    Seller_Type Transmission  Owner  Depreciation
# 86      Dealer       Manual      0          57.6

# %%
#Lowest depreciation observed from the vehicles in the data
df.loc[df.Depreciation==df.Depreciation.min()]
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155  Honda Activa 4G  2017           0.48           0.51        4300
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 155    Petrol  Individual    Automatic      0          0.03

# %% [markdown]
# 12)Which is the most and least cost depreciated vehicle in data ?
#
# Land Cruiser(Most cost depreciated vehicle: 57.6) -> by using df.Depreciation.max()
#
# Honda Activa(Least cost depreciated vehicle: 0.03) -> by using df.Depreciation.min()

# %%
#importing Matplotlib for drawing visualizations
import matplotlib.pyplot as plt

# %%
#importing Seaborn for drawing visualisations
import seaborn as sns

# %%
# Drawing a bar graph for Fuel_Type
df.Fuel_Type.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
#Drawing a pie chart for Fuel_Type
plt.pie(df.Fuel_Type.value_counts(), labels=["Petrol" ,"Diesel","CNG"], shadow =True)
plt.show()

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
#Drawing a pie chart for Seller_Type
plt.pie(df.Seller_Type.value_counts(), labels=["Dealer","Individual"], shadow= True)
plt.show()

# %%
#Drawing a countplot for all the vehicles given in this data
fig_dims = (12,20)
fig ,ax = plt.subplots(figsize = fig_dims)
sns.countplot(y = df.Car_Name,ax = ax ,data = df)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %%
#Drawing a barplot for Car_Name and Cost Depreciation
fig_dims = (12, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x = "Depreciation" ,y = "Car_Name", ax=ax ,data = df)
# Out:
# <Axes: xlabel='Depreciation', ylabel='Car_Name'>

# %% [markdown]
# 13)Which brands of vehicles are less affected by cost depreciation ?
#
# The above barplot of Car_Name and Depreciation gives the visualization analysis for the vehicles that are less affected by cost depreciation.

# %%
#Drawing a scatter plot for Kms_Driven and Depreciation
plt.scatter(df.Kms_Driven,df.Depreciation)
plt.xlabel = "Kilometers Driven"
plt.ylabel = "Cost depriciation in Lakhs"
plt.title = "Cost depriciation vs Kilometers Driven"
plt.show()

# %%
#Drawing a scatter plot for Year and Depreciation
plt.scatter(df.Year,df.Depreciation)
plt.xlabel = "Manufacturing Year"
plt.ylabel = "Cost Depreciation"
plt.title = "Manufacturing Year vs Cost Depreciation"
plt.show()

# %% [markdown]
# 14)Are there any factors which you feel affect the cost depreciation ?
#
#    Kilometers driven(Kms_Driven) and age of vehicle (Year) would affect the cost depreciation. Check the above scatter plots.
#
#    -> plt.scatter(df.Kms_Driven,df.Depreciation)
#
#    -> plt.scatter(df.Year,df.Depreciation)

# %%
#Drawing a scatter plot for Kms_Driven and Selling Price
plt.scatter(df.Kms_Driven,df.Selling_Price)
plt.xlabel = "Kilometers Driven"
plt.ylabel = "Selling Price  in Lakhs"
plt.title = "Selling price vs Kilometers Driven"
plt.show()

# %%
#Drawing a scatter plot for Year and Selling Price
plt.scatter(df.Year,df.Selling_Price)
plt.xlabel = "Manufacturing Year"
plt.ylabel = "Selling Price in Lakhs"
plt.title = "Selling price vs Manufacturing Year"
plt.show()

# %% [markdown]
# 15)In general selling price is affected by age of vehicle and distance driven by vehicle , is it observable from data ?
#
# Yes, Selling price is affected by age of vehicle and distance driven by vehicle.
# This can be observed from the scatterplots of
#
# plt.scatter(df.Kms_Driven,df.Selling_Price)
#
# plt.scatter(df.Year,df.Selling_Price)

# %%
# check out the newest vehicles on sale  -  after 2014 manufactured
new_vehicles = df[df['Year'] > 2014]
new_vehicles.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 2      Dealer       Manual      0          2.60
# 5      Dealer       Manual      0          0.58
# 6      Dealer       Manual      0          1.37
# 7      Dealer       Manual      0          2.11
# 8      Dealer       Manual      0          0.14

# %%
#reset the index of the new_vehicles
new_vehicles.reset_index(drop=True,inplace=True)
new_vehicles.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ciaz  2017           7.25           9.85        6900    Petrol
# 1  vitara brezza  2018           9.25           9.83        2071    Diesel
# 2           ciaz  2015           6.75           8.12       18796    Petrol
# 3        s cross  2015           6.50           8.61       33429    Diesel
# 4           ciaz  2016           8.75           8.89       20273    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 0      Dealer       Manual      0          2.60
# 1      Dealer       Manual      0          0.58
# 2      Dealer       Manual      0          1.37
# 3      Dealer       Manual      0          2.11
# 4      Dealer       Manual      0          0.14

# %%
#Drawing a countplot for new_Vehicles i.e manufactured after 2014
fig_dims = (12,20)
fig ,ax = plt.subplots(figsize = fig_dims)
sns.countplot(y = new_vehicles.Car_Name,ax = ax ,data = new_vehicles)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %% [markdown]
# 16)Can we get idea about newest vehicles i.e. after 2014 manufactured ?
#
#
# The above countplot gives the complete information about count of newest_vehicles i.e after 2014 manufactured and new_vehicles.head() gives the idea about the top 5 vehicles manufactured after 2014.

# %%
#Can we find out data of only two-wheelers from this data?
two_wheelers = df[df["Present_Price"]<3.5]
print(two_wheelers.head())
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 23                    alto k10  2014           2.50           3.46
# 37                         800  2003           0.35           2.28
# 44                        omni  2012           1.25           2.69
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 23        45280    Petrol      Dealer       Manual      0          0.96
# 37       127000    Petrol  Individual       Manual      0          1.93
# 44        50000    Petrol      Dealer       Manual      0          1.44
# 100        3000    Petrol  Individual       Manual      0          0.15
# 101        1400    Petrol  Individual       Manual      0          0.12

# %%
#reset the index of two_wheelers
two_wheelers.reset_index(drop=True,inplace=True)
two_wheelers.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                   alto k10  2014           2.50           3.46       45280
# 1                        800  2003           0.35           2.28      127000
# 2                       omni  2012           1.25           2.69       50000
# 3  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 4         UM Renegade Mojave  2017           1.70           1.82        1400
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 0    Petrol      Dealer       Manual      0          0.96
# 1    Petrol  Individual       Manual      0          1.93
# 2    Petrol      Dealer       Manual      0          1.44
# 3    Petrol  Individual       Manual      0          0.15
# 4    Petrol  Individual       Manual      0          0.12

# %%
#Finding two_wheelers excluding "alto k10","800","Omni"
two_wheelers = two_wheelers.loc[two_wheelers.Car_Name != "alto k10"]
two_wheelers = two_wheelers.loc[two_wheelers.Car_Name != "800"]
two_wheelers = two_wheelers.loc[two_wheelers.Car_Name != "omni"]
two_wheelers.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 3  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 4         UM Renegade Mojave  2017           1.70           1.82        1400
# 5                  KTM RC200  2017           1.65           1.78        4000
# 6          Bajaj Dominar 400  2017           1.45           1.60        1200
# 7  Royal Enfield Classic 350  2017           1.35           1.47        4100
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 3    Petrol  Individual       Manual      0          0.15
# 4    Petrol  Individual       Manual      0          0.12
# 5    Petrol  Individual       Manual      0          0.13
# 6    Petrol  Individual       Manual      0          0.15
# 7    Petrol  Individual       Manual      0          0.12

# %%
two_wheelers.reset_index(drop=True,inplace=True)
two_wheelers.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 1         UM Renegade Mojave  2017           1.70           1.82        1400
# 2                  KTM RC200  2017           1.65           1.78        4000
# 3          Bajaj Dominar 400  2017           1.45           1.60        1200
# 4  Royal Enfield Classic 350  2017           1.35           1.47        4100
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 0    Petrol  Individual       Manual      0          0.15
# 1    Petrol  Individual       Manual      0          0.12
# 2    Petrol  Individual       Manual      0          0.13
# 3    Petrol  Individual       Manual      0          0.15
# 4    Petrol  Individual       Manual      0          0.12

# %%
#Drawing a Countplot for two_wheelers
fig_dims = (12,20)
fig ,ax = plt.subplots(figsize = fig_dims)
sns.countplot(y = two_wheelers.Car_Name,ax = ax ,data = two_wheelers)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %% [markdown]
# 17)Can we find out data of only two wheelers from this data ?
#
# The above countplot gives the count of two wheelers from this data using Seaborn and two_wheelers.head() gives the top 5 names of the two_wheelers excluding "alto K10" , "800" , "Omni" .

# %%
#Which is the oldest bike sold here?
two_wheelers.loc[two_wheelers.Year == two_wheelers.Year.min()]
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 89  Hero Super Splendor  2005            0.2           0.57       55000
#
#    Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 89    Petrol  Individual       Manual      0          0.37

# %% [markdown]
# 17)Which is the oldest bike sold here?
#
# Hero Super Splendor is the oldest bike sold.
#
# -> using two_wheelers.loc[two_wheelers.Year == two_wheelers.Year.min()]

# %%
#Which is the newest bike sold here?
two_wheelers.loc[two_wheelers.Year == two_wheelers.Year.max()]
# Out:
#                      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 1          UM Renegade Mojave  2017           1.70           1.82        1400
# 2                   KTM RC200  2017           1.65           1.78        4000
# 3           Bajaj Dominar 400  2017           1.45           1.60        1200
# 4   Royal Enfield Classic 350  2017           1.35           1.47        4100
# 9   Royal Enfield Classic 350  2017           1.20           1.47       11000
# 26          Bajaj Avenger 220  2017           0.90           0.95        1300
# 28       Honda CB Hornet 160R  2017           0.80           0.87        3000
# 29          Yamaha FZ S V 2.0  2017           0.78           0.84        5000
# 30       Honda CB Hornet 160R  2017           0.75           0.87       11000
# 32          Bajaj Avenger 220  2017           0.75           0.95        3500
# 34         TVS Apache RTR 160  2017           0.65           0.81       11800
# ...

# %% [markdown]
# 18)Which is the newest bike sold here?
#
#   There are many newest bikes sold and can be found using
#
#   -> two_wheelers.loc[two_wheelers.Year == two_wheelers.Year.max()]

# %%
#Most sold bike here?
two_wheelers[two_wheelers.Selling_Price>1.6]
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 1         UM Renegade Mojave  2017           1.70           1.82        1400
# 2                  KTM RC200  2017           1.65           1.78        4000
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 0    Petrol  Individual       Manual      0          0.15
# 1    Petrol  Individual       Manual      0          0.12
# 2    Petrol  Individual       Manual      0          0.13

# %% [markdown]
# 19)Which is the most sold bike here?
#
# Royal Enfield Thunder 500, UM Renegade Mojave, KTM RC200 are the most sold bikes.
#
# -> two_wheelers[two_wheelers.Selling_Price>1.6]

# %%
# to check whether any deal  about two wheelers exceeded general expectation
plt.boxplot(two_wheelers.Selling_Price)
plt.show()

# %% [markdown]
# 20)Do you find any deal in two wheelers which exceeded the general expectation ? Can you find reason for it ?
#
# Yes, The above boxplot gives an information whether any deal in two wheelers which exceeded the general expectation.

# %%
Cars = df[df["Present_Price"]>3.5]
print(Cars.head())
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 0      Dealer       Manual      0          2.24
# 1      Dealer       Manual      0          4.79
# 2      Dealer       Manual      0          2.60
# 3      Dealer       Manual      0          1.30
# 4      Dealer       Manual      0          2.27

# %%
# Reset the index of Cars.head()
Cars.reset_index(drop=True,inplace=True)
Cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 0      Dealer       Manual      0          2.24
# 1      Dealer       Manual      0          4.79
# 2      Dealer       Manual      0          2.60
# 3      Dealer       Manual      0          1.30
# 4      Dealer       Manual      0          2.27

# %%
#Drawing a countplot for only Cars in this data
fig_dims = (12,20)
fig ,ax = plt.subplots(figsize = fig_dims)
sns.countplot(y = Cars.Car_Name,ax = ax ,data = Cars)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %% [markdown]
# 21)Can we find out data of only cars from this data ?
#
# Yes, the above countplot gives the information about only Cars from this data.

# %%
#Which is the oldest Car sold here?
Cars.loc[Cars.Year == Cars.Year.min()]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 37      sx4  2003           2.25           7.98       62000    Petrol
#
#    Seller_Type Transmission  Owner  Depreciation
# 37      Dealer       Manual      0          5.73

# %% [markdown]
# 22)Which is the oldest car sold here?
#
# The oldest Car sold here is "sx4" using
#
# -> Cars.loc[Cars.Year == Cars.Year.min()]

# %%
#Which is the newest Car sold here?
Cars.loc[Cars.Year == Cars.Year.max()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 5      Dealer       Manual      0          0.58

# %% [markdown]
# 23)Which is the newest car sold here?
#
# The newest Car sold here is "vitara brezza" using
#
# -> Cars.loc[Cars.Year == Cars.Year.max()]

# %%
# to check whether any deal  about two wheelers exceeded general expectation
plt.boxplot(Cars.Selling_Price)
plt.show()

# %% [markdown]
# 24)Do you find any deal in cars which exceeded the general expectation ? Can you find reason for it ?
#
# Yes, The above boxplot gives the information if any deal in Cars which exceeded the general expectation.
